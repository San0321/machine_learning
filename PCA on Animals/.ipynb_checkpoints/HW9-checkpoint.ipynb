# %%
import numpy as np
import sklearn as sklearn
from math import exp, fabs
import matplotlib.pyplot as plt

data1 = np.genfromtxt("predicates.txt", dtype=None, delimiter=",")
data2 = np.genfromtxt("classes.txt",dtype=None)
data3 = np.genfromtxt("predicate-matrix-continuous.txt",dtype='f8')

# %%
print data2
print data2.shape
# Out:
# [( 1, 'antelope') ( 2, 'grizzly+bear') ( 3, 'killer+whale') ( 4, 'beaver')
#  ( 5, 'dalmatian') ( 6, 'persian+cat') ( 7, 'horse')
#  ( 8, 'german+shepherd') ( 9, 'blue+whale') (10, 'siamese+cat')
#  (11, 'skunk') (12, 'mole') (13, 'tiger') (14, 'hippopotamus')
#  (15, 'leopard') (16, 'moose') (17, 'spider+monkey') (18, 'humpback+whale')
#  (19, 'elephant') (20, 'gorilla') (21, 'ox') (22, 'fox') (23, 'sheep')
#  (24, 'seal') (25, 'chimpanzee') (26, 'hamster') (27, 'squirrel')
#  (28, 'rhinoceros') (29, 'rabbit') (30, 'bat') (31, 'giraffe') (32, 'wolf')
#  (33, 'chihuahua') (34, 'rat') (35, 'weasel') (36, 'otter') (37, 'buffalo')
#  (38, 'zebra') (39, 'giant+panda') (40, 'deer') (41, 'bobcat') (42, 'pig')
#  (43, 'lion') (44, 'mouse') (45, 'polar+bear') (46, 'collie')
#  (47, 'walrus') (48, 'raccoon') (49, 'cow') (50, 'dolphin')]
# (50,)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
y_pca = pca.fit_transform(data3)
x_data = []
y_data = []
animals = []
print y_pca
for a in range(len(y_pca)):
    x_data.append(y_pca[a][0])
    y_data.append(y_pca[a][1])

    
for c in range(len(data2)):
    animals.append(data2[c][1])
    
for b in range(len(y_pca)):
    plt.annotate(animals[b], xy=(x_data[b],y_data[b]), xytext=(x_data[b]+1,y_data[b]+0.5))
    
#print data3.shape
#x_pca = PCA.transform(data3)
plt.scatter(x_data, y_data)
#print pca
plt.show()


'''
reduced_data = PCA(n_components=2).fit_transform(data3)
#PCA.fit(data1,data2)
#PCA.predict()
plt.show()plt.show()'''
# Out:
# [[  14.33200256 -106.35992505]
#  [ -58.9630861    76.22681969]
#  [ 170.08767172  139.3662367 ]
#  [  31.85582565   54.04638157]
#  [ -29.65753503   11.3917049 ]
#  [ -40.87859041   10.72272289]
#  [   1.17791115 -104.79228138]
#  [ -82.43016284   45.38757524]
#  [ 211.92608739   82.83737143]
#  [ -90.92835147   43.3052917 ]
#  [ -58.01597662  -35.20297112]
#  [ -33.18440666  -20.17533047]
#  [-127.19955243   92.38136512]
#  [ 129.48931695  -24.05695316]
#  [-117.35250987   89.2965802 ]
#  [  28.55636713 -129.17123958]
#  [ -43.49964663   -6.27693742]
#  [ 226.54893728   95.28906181]
#  [  95.64111855  -85.05034027]
#  [ -18.3316707    -1.34492612]
#  [  56.58550468 -120.70785352]
#  [-111.97091878   74.12827031]
#  [  25.79398483 -132.31759287]
#  [ 151.36316459  100.93057781]
#  [ -67.92677834  -19.55128584]
#  [ -48.25033667  -49.77147826]
#  [ -61.48822496  -11.07402232]
#  [  96.32422934  -65.00899433]
#  [ -32.71055049  -68.2626778 ]
#  [ -55.32175189   58.45553839]
# ...

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10,10
